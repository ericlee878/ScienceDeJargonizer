# %%
import numpy as np
import pandas as pd
import json

# %%
# Load the jargon annotated data
merged_humam_llm_jargon = pd.read_json(
    "data/llm_outputs/240525_march_2024_human_llm_jargon_merged.json", 
    orient="index"
)

merged_humam_llm_jargon.head()
# Out:
#        arxiv_id reader_id                                   gpt4_jargon_list  \
# 0  2403.16190v1      rid0  reject option strategy, formal guarantees, min...
# 1  2403.16190v1      rid1  linear classification problems, reject option ...
# 2  2307.05300v4      rid0  cognitive synergist, fine-grained personas, fa...
# 3  2307.05300v4      rid1  cognitive synergy, cognitive synergist, multi-...
# 4  2403.16750v1      rid0  Common Weakness Enumerations (CWEs), SystemVer...
#
#                                    human_jargon_list
# 0                     correctness,minimality,Anchors
# 1  reject option strategy,Anchors,heuristic algor...
# 2                                 multi-turn,persona
# 3  Solo Performance Prompting,multi-turn,Chain-of...
# 4  common weakeness enumerations,SystemVerilog,Re...

# %% [markdown]
# # Create an Eval File

# %%
# Load in outputs
gpt4_rag = pd.read_json(
    "data/llm_outputs/240528_march_2024_sampled_jargon_definitions_rag.json", 
    orient="records"
)

# Add column
gpt4_rag['model'] = ['gpt4_rag']*len(gpt4_rag)

gpt4_rag.head()
# Out:
#        arxiv_id reader_id       human_jargon_term  \
# 0  2403.16190v1      rid0             correctness
# 1  2403.16190v1      rid0              minimality
# 2  2403.16190v1      rid0                 Anchors
# 3  2403.16190v1      rid1  reject option strategy
# 4  2403.16190v1      rid1                 Anchors
#
#                                      definition_text     model
# 0  Correctness in this context refers to whether ...  gpt4_rag
# 1  Minimality refers to the concept of using the ...  gpt4_rag
# 2  Anchors is a method used in the field of artif...  gpt4_rag
# 3  The reject option strategy in classification m...  gpt4_rag
# 4  Anchors is a method used in artificial intelli...  gpt4_rag

# %%
# Load in outputs
gpt4_abstract = pd.read_json(
    "data/llm_outputs/240528_march_2024_sampled_jargon_definitions_abstract.json", 
    orient="records"
)

# Add column
gpt4_abstract['model'] = ['gpt4_abstract']*len(gpt4_abstract)

gpt4_abstract.head()
# Out:
#        arxiv_id reader_id       human_jargon_term  \
# 0  2403.16190v1      rid0             correctness
# 1  2403.16190v1      rid0              minimality
# 2  2403.16190v1      rid0                 Anchors
# 3  2403.16190v1      rid1  reject option strategy
# 4  2403.16190v1      rid1                 Anchors
#
#                                      definition_text          model
# 0  Correctness, in this context, refers to the de...  gpt4_abstract
# 1  In the given context, "minimality" refers to t...  gpt4_abstract
# 2  In the given context, "Anchors" refers to a ty...  gpt4_abstract
# 3  A reject option strategy in machine learning i...  gpt4_abstract
# 4  Anchors is an algorithm used to explain the de...  gpt4_abstract

# %%
# Stack the two dfs
concatenated = pd.concat([gpt4_rag, gpt4_abstract], ignore_index=True, axis=0)
concatenated.head()
# Out:
#        arxiv_id reader_id       human_jargon_term  \
# 0  2403.16190v1      rid0             correctness
# 1  2403.16190v1      rid0              minimality
# 2  2403.16190v1      rid0                 Anchors
# 3  2403.16190v1      rid1  reject option strategy
# 4  2403.16190v1      rid1                 Anchors
#
#                                      definition_text     model
# 0  Correctness in this context refers to whether ...  gpt4_rag
# 1  Minimality refers to the concept of using the ...  gpt4_rag
# 2  Anchors is a method used in the field of artif...  gpt4_rag
# 3  The reject option strategy in classification m...  gpt4_rag
# 4  Anchors is a method used in artificial intelli...  gpt4_rag

# %%
# Randomize row ordering + also maintain all the arXiv IDs next to each other
concatenated = concatenated.sample(frac=1).reset_index(drop=True)
concatenated.sort_values(['arxiv_id', 'human_jargon_term'], inplace=True)
concatenated.head(20)
# Out:
#          arxiv_id reader_id                   human_jargon_term  \
# 145  2007.00714v4      rid1                               ANOVA
# 288  2007.00714v4      rid1                               ANOVA
# 645  2007.00714v4      rid1                                 DAG
# 646  2007.00714v4      rid1                                 DAG
# 154  2007.00714v4      rid1        Shapley based symmetrization
# 380  2007.00714v4      rid0        Shapley based symmetrization
# 406  2007.00714v4      rid0        Shapley based symmetrization
# 600  2007.00714v4      rid1        Shapley based symmetrization
# 527  2007.00714v4      rid1                  joint distribution
# 686  2007.00714v4      rid1                  joint distribution
# 100  2007.00714v4      rid1                             perturb
# 381  2007.00714v4      rid1                             perturb
# 596  2007.00714v4      rid0                   relabelling nodes
# 616  2007.00714v4      rid0                   relabelling nodes
# 69   2007.00714v4      rid1  structure-preserving interventions
# 157  2007.00714v4      rid0  structure-preserving interventions
# 437  2007.00714v4      rid0  structure-preserving interventions
# 691  2007.00714v4      rid1  structure-preserving interventions
# 232  2007.00714v4      rid1                         target node
# 537  2007.00714v4      rid1                         target node
#
#                                        definition_text          model
# 145  ANOVA, or Analysis of Variance, is a statistic...  gpt4_abstract
# 288  ANOVA, or Analysis of Variance, is a statistic...       gpt4_rag
# 645  A Directed Acyclic Graph (DAG) is a type of di...       gpt4_rag
# 646  A Directed Acyclic Graph (DAG) is a diagram th...  gpt4_abstract
# 154  Shapley based symmetrization is a method used ...  gpt4_abstract
# 380  Shapley based symmetrization is a method that ...       gpt4_rag
# 406  Shapley based symmetrization is a method used ...  gpt4_abstract
# 600  Shapley based symmetrization is a method used ...       gpt4_rag
# 527  The term "joint distribution" refers to the wa...  gpt4_abstract
# 686  A joint distribution is a way to describe how ...       gpt4_rag
# 100  To "perturb" means to disturb or alter somethi...       gpt4_rag
# 381  The term "perturb" means to disturb or alter s...  gpt4_abstract
# 596  Relabelling nodes refers to renaming the point...       gpt4_rag
# 616  Relabelling nodes refers to changing the names...  gpt4_abstract
# 69   Structure-preserving interventions are a metho...       gpt4_rag
# 157  Structure-preserving interventions are changes...  gpt4_abstract
# 437  Structure-preserving interventions are a type ...       gpt4_rag
# 691  Structure-preserving interventions are changes...  gpt4_abstract
# 232  A target node is simply the end point in a net...       gpt4_rag
# 537  In the context of the given abstract, a "targe...  gpt4_abstract

# %%
concatenated.loc[
    concatenated['reader_id'] =='rid1'
].to_csv('data/240528_rid1_jargon_pref_annotations_incomplete.csv', index=False)

# %%
concatenated.loc[
    concatenated['reader_id'] =='rid0'
].to_csv('data/240528_rid0_jargon_pref_annotations_incomplete.csv', index=False)

# %% [markdown]
# # Assess the Eval File

# %%
# Read in the completed jargon preference annotations
rid0 = pd.read_csv('data/human_annotations/240528_rid0_jargon_pref_annotations_complete.csv')
rid1 = pd.read_csv('data/human_annotations/240528_rid1_jargon_pref_annotations_complete.csv')

rid0.fillna("", inplace=True)
rid1.fillna("", inplace=True)

# %%
rid1.columns
# Out:
# Index(['arxiv_id', 'reader_id', 'human_jargon_term', 'definition_text',
#        'model', 'Accuracy ', 'Ranking', 'Notes'],
#       dtype='object')

# %%
rid0.columns
# Out:
# Index(['arxiv_id', 'reader_id', 'human_jargon_term', 'definition_text',
#        'model', 'Accuracy', 'Ranking', 'Notes'],
#       dtype='object')

# %%
# Rename
rid1.rename({'Accuracy ': 'Accuracy'}, axis=1, inplace=True)
rid1.columns
# Out:
# Index(['arxiv_id', 'reader_id', 'human_jargon_term', 'definition_text',
#        'model', 'Accuracy', 'Ranking', 'Notes'],
#       dtype='object')

# %%
# Concat the dfs
rid0_rid1 = pd.concat([rid0, rid1], axis=0)
rid0_rid1.head()
# Out:
#        arxiv_id reader_id                   human_jargon_term  \
# 0  2007.00714v4      rid0        Shapley based symmetrization
# 1  2007.00714v4      rid0        Shapley based symmetrization
# 2  2007.00714v4      rid0                   relabelling nodes
# 3  2007.00714v4      rid0                   relabelling nodes
# 4  2007.00714v4      rid0  structure-preserving interventions
#
#                                      definition_text          model  Accuracy  \
# 0  Shapley based symmetrization is a method that ...       gpt4_rag  accurate
# 1  Shapley based symmetrization is a method used ...  gpt4_abstract  accurate
# 2  Relabelling nodes refers to changing the names...  gpt4_abstract  accurate
# 3  Relabelling nodes refers to renaming the point...       gpt4_rag  accurate
# 4  Structure-preserving interventions are changes...  gpt4_abstract  accurate
#
#    Ranking                        Notes
# 0        1
# 1        2
# 2        1
# 3        2               too simplified
# 4        2  a bit contrived in phrasing

# %%
rid0_rid1.tail()
# Out:
#          arxiv_id reader_id       human_jargon_term  \
# 467  2403.17873v1      rid1  social misattributions
# 468  2403.19436v1      rid1     dearthneoliberalism
# 469  2403.19436v1      rid1     dearthneoliberalism
# 470  2403.19436v1      rid1             gig economy
# 471  2403.19436v1      rid1             gig economy
#
#                                        definition_text          model  \
# 467  Social misattributions refer to situations whe...  gpt4_abstract
# 468  The term "dearth" refers to a scarcity or lack...  gpt4_abstract
# 469  It seems there may be a typo in your query. If...       gpt4_rag
# 470  The gig economy refers to a labor market chara...  gpt4_abstract
# 471  The gig economy is a labor market consisting o...       gpt4_rag
#
#         Accuracy  Ranking Notes
# 467     accurate        0
# 468     accurate        1
# 469  no response        2
# 470     accurate        0
# 471     accurate        0

# %% [markdown]
# # Accuracy

# %%
rid0_rid1['model'].value_counts()

# %%
rid0_rid1.groupby(['reader_id'])['Accuracy'].value_counts(normalize=True)

# %%
rid0_rid1['Accuracy'].value_counts(normalize=True)

# %%
rid0_rid1.groupby(['model'])['Accuracy'].value_counts(normalize=True)

# %%
# View the inaccuracies where BOTH got it wrong
inaccuracies = rid0_rid1.loc[
    rid0_rid1['Accuracy']=='inaccurate'
].reset_index(drop=True)

print(inaccuracies.loc[inaccuracies.duplicated('human_jargon_term', keep=False)].shape)

inaccuracies.loc[inaccuracies.duplicated('human_jargon_term', keep=False)]

# %%
rid0_rid1.loc[
    rid0_rid1['Accuracy']=='inaccurate'
].reset_index(drop=True)['model'].value_counts()

# %%
rid1.loc[
    rid1['Accuracy']=='inaccurate'
].reset_index(drop=True)['model'].value_counts()

# %% [markdown]
# # Wins and Losses

# %%
# Drop any abstracts where one or more responses are inaccurate
rid0_rid1_accurate = rid0_rid1.loc[
    rid0_rid1['Accuracy']=='accurate'
]

# Now drop human_jargon_term that only have one item, because you need the paired defitions -- use duplicated
rid0_rid1_accurate = rid0_rid1_accurate.loc[rid0_rid1_accurate.duplicated(subset='human_jargon_term', keep=False)]
rid0_rid1_accurate.head()

# %%
rid0_rid1_accurate['Ranking'].value_counts()

# %% [markdown]
# 1s and 2s express preferences, 0s and -1s express ties

# %%
# For the purpose of this exercise, set all -1s to 0
rid0_rid1_accurate = rid0_rid1_accurate.replace(-1, 0)
rid0_rid1_accurate['Ranking'].value_counts()

# %%
# Do % wins and losses

# Create a new column 'result' based on the 'ranking' column
rid0_rid1_accurate['result'] = rid0_rid1_accurate['Ranking'].apply(lambda x: 'win' if x == 1 else ('loss' if x == 2 else 'tie'))

# Group by 'model' and 'result', count the occurrences, and calculate the percentages
result_counts = rid0_rid1_accurate.groupby(['model', 'result']).size().unstack(fill_value=0)
result_percentages = result_counts.div(result_counts.sum(axis=1), axis=0) * 100

# Display the result percentages
print(result_percentages)

# %%
# Group by 'annotator_id', 'model', and 'result', count the occurrences, and calculate the percentages
result_counts = rid0_rid1_accurate.groupby(['reader_id', 'model', 'result']).size().unstack(fill_value=0)
result_percentages = result_counts.div(result_counts.sum(axis=1), axis=0) * 100

# Display the result percentages
print(result_percentages)

# %% [markdown]
# # Making a Dataset for Display

# %%
rid0_rid1.head()
# Out:
#        arxiv_id reader_id                   human_jargon_term  \
# 0  2007.00714v4      rid0        Shapley based symmetrization
# 1  2007.00714v4      rid0        Shapley based symmetrization
# 2  2007.00714v4      rid0                   relabelling nodes
# 3  2007.00714v4      rid0                   relabelling nodes
# 4  2007.00714v4      rid0  structure-preserving interventions
#
#                                      definition_text          model  Accuracy  \
# 0  Shapley based symmetrization is a method that ...       gpt4_rag  accurate
# 1  Shapley based symmetrization is a method used ...  gpt4_abstract  accurate
# 2  Relabelling nodes refers to changing the names...  gpt4_abstract  accurate
# 3  Relabelling nodes refers to renaming the point...       gpt4_rag  accurate
# 4  Structure-preserving interventions are changes...  gpt4_abstract  accurate
#
#    Ranking                        Notes
# 0        1
# 1        2
# 2        1
# 3        2               too simplified
# 4        2  a bit contrived in phrasing

# %%
# Drop rid0's terms
display_data = rid0_rid1.loc[
    rid0_rid1['reader_id']=='rid1'
]
# Keep gpt4_abstract terms
display_data = display_data.loc[
    display_data['model']=='gpt4_abstract'
]
# Now drop the inaccurate one
display_data = display_data.loc[
    display_data['Accuracy']=='accurate'
]

# %%
display_data.shape
# Out:
# (233, 8)

# %%
display_data
# Out:
#          arxiv_id reader_id                    human_jargon_term  \
# 1    2007.00714v4      rid1                                ANOVA
# 3    2007.00714v4      rid1                                  DAG
# 5    2007.00714v4      rid1         Shapley based symmetrization
# 7    2007.00714v4      rid1                   joint distribution
# 8    2007.00714v4      rid1                              perturb
# ..            ...       ...                                  ...
# 462  2403.17873v1      rid1  Social\nTransparency (ST) framework
# 465  2403.17873v1      rid1                  epistemic injustice
# 467  2403.17873v1      rid1               social misattributions
# 468  2403.19436v1      rid1                  dearthneoliberalism
# 470  2403.19436v1      rid1                          gig economy
#
#                                        definition_text          model  \
# 1    ANOVA, or Analysis of Variance, is a statistic...  gpt4_abstract
# 3    A Directed Acyclic Graph (DAG) is a diagram th...  gpt4_abstract
# 5    Shapley based symmetrization is a method used ...  gpt4_abstract
# 7    The term "joint distribution" refers to the wa...  gpt4_abstract
# 8    The term "perturb" means to disturb or alter s...  gpt4_abstract
# ..                                                 ...            ...
# 462  The Social Transparency (ST) framework is desi...  gpt4_abstract
# 465  Epistemic injustice occurs when someone is unf...  gpt4_abstract
# 467  Social misattributions refer to situations whe...  gpt4_abstract
# 468  The term "dearth" refers to a scarcity or lack...  gpt4_abstract
# 470  The gig economy refers to a labor market chara...  gpt4_abstract
#
#      Accuracy  Ranking Notes
# 1    accurate        2
# 3    accurate        2
# 5    accurate        0
# 7    accurate        2
# 8    accurate        2
# ..        ...      ...   ...
# 462  accurate        0
# 465  accurate        0
# 467  accurate        0
# 468  accurate        1
# 470  accurate        0
#
# [233 rows x 8 columns]

# %%
# Read in the arXiv metadata
with open("data/arxiv_metadata/filtered/march_2024_ai_hc_cy_peer_reviewed_sampled.json") as json_data:
    metadata = json.load(json_data)
    json_data.close()

# Convert JSON to DataFrame
metadata_df = pd.DataFrame.from_dict(metadata, orient='index')

metadata_df.head()
# Out:
#        arxiv_id                                url  \
# 0  2403.16190v1  http://arxiv.org/abs/2403.16190v1
# 1  2307.05300v4  http://arxiv.org/abs/2307.05300v4
# 2  2403.16750v1  http://arxiv.org/abs/2403.16750v1
# 3  2311.10112v2  http://arxiv.org/abs/2311.10112v2
# 4  2310.08992v3  http://arxiv.org/abs/2310.08992v3
#
#                                                title  \
# 0  Logic-based Explanations for Linear Support Ve...
# 1  Unleashing the Emergent Cognitive Synergy in L...
# 2  All Artificial, Less Intelligence: GenAI throu...
# 3  zrLLM: Zero-Shot Relational Learning on Tempor...
# 4  CodeChain: Towards Modular Code Generation Thr...
#
#                                              summary        updated  \
# 0  Support Vector Classifier (SVC) is a well-know...  1711293284000
# 1  Human intelligence thrives on cognitive synerg...  1711463553000
# 2  Modern hardware designs have grown increasingl...  1711373004000
# 3  Modeling evolving knowledge over temporal know...  1710517087000
# 4  Large Language Models (LLMs) have already beco...  1710386949000
#
#        published                                            authors  \
# 0  1711293284000  [Francisco Mateus Rocha Filho, Thiago Alves Ro...
# 1  1689086719000  [Zhenhailong Wang, Shaoguang Mao, Wenshan Wu, ...
# 2  1711373004000  [Deepak Narayan Gadde, Aman Kumar, Thomas Nala...
# 3  1700083515000  [Zifeng Ding, Heling Cai, Jingpei Wu, Yunpu Ma...
# 4  1697192268000  [Hung Le, Hailin Chen, Amrita Saha, Akash Goku...
#
#                                             comments  \
# 0  16 pages, submitted to BRACIS 2023 (Brazilian ...
# 1  Accepted as a main conference paper at NAACL 2024
# 2                       Published in DVCon U.S. 2024
# 3             Accepted to NAACL 2024 main conference
# 4                              Accepted to ICLR 2024
#
#                             categories primary_category  \
# 0  [cs.AI, cs.LG, cs.LO, I.2.4; I.2.6]            cs.AI
# 1                       [cs.AI, cs.CL]            cs.AI
# 2                              [cs.AI]            cs.AI
# 3                [cs.AI, cs.CL, cs.LG]            cs.AI
# 4                [cs.AI, cs.CL, cs.PL]            cs.AI
#
#                             doi journal_ref  peer_reviewed
# 0  10.1007/978-3-031-45368-7_10        None           True
# 1                          None        None           True
# 2                          None        None           True
# 3                          None        None           True
# 4                          None        None           True

# %%
# Merge
display_data_final = pd.merge(metadata_df, display_data, on='arxiv_id')
display_data_final.shape
# Out:
# (233, 20)

# %%
# Save to JSON
display_data_final.to_json(
    'data/data_for_display.json', orient='index'
)
